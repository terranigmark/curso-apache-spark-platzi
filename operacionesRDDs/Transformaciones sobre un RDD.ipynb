# %%
from pyspark import SparkContext
sc = SparkContext(master = "local", appName = "Transformaciones sobre un RDD")

# %%
path = "../proyecto/"
equiposOlimpicosRDD = sc.textFile(path+"paises.csv",2).map(lambda line : line.split(","))

# %%
equiposOlimpicosRDD.map(lambda x : (x[2])).distinct().count()
# Out:
# 249

# %%
equiposOlimpicosRDD.map(lambda x : (x[2],x[1])).groupByKey().mapValues(list).collect()
# Out:
# [('ARG',
#   ['Acturus',
#    'Antares',
#    'Arcturus',
#    'Ardilla',
#    'Argentina',
#    'Argentina-1',
#    'Argentina-2',
#    'Blue Red',
#    'Covunco III',
#    'Cupidon III',
#    'Djinn',
#    'Gullvinge',
#    'Matrero II',
#    'Mizar',
#    'Pampero',
#    'Rampage',
#    'Tango',
#    'Wiking']),
#  ('AFG', ['Afghanistan']),
#  ('IRL',
#   ['Akatonbo',
#    'Aletta',
#    'Ireland',
#    'Ireland-1',
#    'Ireland-2',
#    'The Cloud',
#    'Three Leaves']),
#  ('POR',
#   ['Alcaid',
#    'Argus',
#    'Calcinhas',
#    'Camelia',
#    'Ciocca III',
#    'Espadarte',
#    'Espardate',
#    'Faneca',
#    'Galopin De La Font',
#    'Grifo III',
#    'Grifo IV',
#    'Hannover',
#    "Ma'Lindo",
#    'Notavel',
#    'Oxalis',
#    'Portugal',
#    'Portugal-1',
#    'Portugal-2',
#    'Sjhxa',
#    'Symphony',
#    'Vicking']),
#  ('AUS',
#   ['Amateur Athletic Association',
#    'Australia',
#    'Australia-1',
#    'Australia-2',
#    'Australia-3',
#    'Australia/Great Britain',
#    'Barrenjoey',
#    'Buraddoo',
#    'Cambria',
#    'Diablo',
#    'Falcon IV',
#    'Falcon VI',
#    'Gabbiano',
#    'Greenoaks Dundee',
#    'Hornet',
#    'Maryke',
#    'Moorina',
#    'Naiad',
#    'Pakaria',
#    'Paula',
#    'Quando Quando',
#    'Relampago',
#    'Vinha']),
#  ('USA',
#   ['Angelita',
#    'Angerburg',
#    'Aphrodite',
#    'Atalanta Boat Club-1',
#    'Atalanta Boat Club-2',
#    'Babe',
#    'Bingo',
#    'Boston Archers',
#    'Brentina',
#    'Century Boat Club-1',
#    'Chicago Archers',
#    'Chicago Athletic Association',
#    'Chicago Athletic Association-2',
#    "Christian Brothers' College-1",
#    'Cincinnati Archers',
#    'Comanche',
#    'Complex II',
#    'Formosa',
#    'Foxhunters Hurlingham',
#    'Frieda',
#    'Frimousse',
#    'Gallant',
#    'Glider',
#    'Hilarius',
#    'Independent Rowing Club-3',
#    'Jupiter',
#    'Kathleen',
#    'Llanoria',
#    'Margaret',
#    'Milwaukee Athletic Club-1',
#    'Minotaur',
#    'Missouri Athletic Club-3',
#    'Mound City Rowing Club-2',
#    'Mystery',
#    'Mythilus',
#    'New York Athletic Club',
#    'New York Athletic Club #1-1',
#    'New York Athletic Club #2-4',
#    'New York Athletic Club-1',
#    'New York Athletic Club-4',
#    'Potomac Archers',
#    'Ravel',
#    'Ravenswood Boat Club-2',
#    'Rhythm',
#    'Rush IV',
#    'Seawanhaka Boat Club-1',
#    'Shrew II',
#    'Skidoo',
#    'Spirit III',
#    'Spirit VI',
#    'St. Louis Amateur Athletic Association',
#    'St. Louis Southwest Turnverein #1-2',
#    'St. Louis Southwest Turnverein #2-3',
#    'St. Rose-2',
#    'Three Star Too',
#    'Tineke',
#    'Trans-Mississippi Golf Association-2',
#    'United States',
#    'United States Golf Association-3',
#    'United States-1',
#    'United States-10',
#    'United States-11',
#    'United States-12',
#    'United States-13',
#    'United States-14',
#    'United States-2',
#    'United States-3',
#    'United States-4',
#    'United States-5',
#    'United States-6',
#    'United States-7',
#    'United States-8',
#    'United States-9',
#    'United States/Great Britain',
#    'Vesper Boat Club',
#    'Vim III',
#    'Western Golf Association-1',
#    'Western Rowing Club-3',
#    'Widgeon']),
#  ('ANG', ['Angola']),
#  ('DEN',
#   ['Anitra',
#    'Bonzo',
#    'Chok',
#    'Clearwater',
#    'Dansk Idrts Forbund',
#    'Denmark',
#    'Denmark-1',
#    'Denmark-2',
#    'Denmark-3',
#    'Denmark-4',
#    'Digby',
#    'Don Schufro',
#    'Hi-Hi',
#    'Jill',
#    'Kiel',
#    'Miss Denmark 1964',
#    'Morena',
#    'Nurdug II',
#    'Nykjbings paa Falster',
#    'Polyteknisk Roklub-1',
#    'Roklubb Kbnhavn-2',
#    'Skum',
#    'Snap',
#    'Snude',
#    'Tip',
#    'Web II',
#    'Web III',
#    'White Lady']),
#  ('ANT', ['Antigua and Barbuda']),
#  ('CAN',
#   ['Argo II',
#    'Argonaut Rowing Club',
#    'Ariel',
#    'Canada',
#    'Canada-1',
#    'Canada-2',
#    'Canada-3',
#    'Caprice',
#    'Dresden',
#    'Galt Football Club',
#    'Glisten',
#    'Gran Gesto',
#    'Jet',
#    'Mad Dog',
#    'Manana',
#    'Mohawk Indians-2',
#    'Orion',
#    'Pop Art',
#    'SagaII',
#    'Santa Maria',
#    'Scaup',
#    'Scram',
#    'Serendipity',
#    'State VI',
#    'Syndi',
#    'Tomahawk II',
#    'Toronto Argonauts',
#    'Trickson VI',
#    'Whirlaway',
#    'Windor',
#    'Winnipeg Shamrocks-1']),
#  ('GER',
#   ['Aschenbrodel',
#    'Bellatrix IX',
#    'Bellatrix XIII',
#    'Berliner Ruderclub',
#    'Berliner Ruderclub Sport-Borussia-1',
#    'Berliner Ruderverein von 1876-2',
#    'Bonaparte',
#    'Bronia',
#    'Deutscher Schwimm Verband Berlin',
#    'Dinah V',
#    'Elvis Va',
#    'Favorite Hammonia-3',
#    'Frankfurt Club',
#    'Germania II',
#    'Germany',
#    'Germany-1',
#    'Germany-2',
#    'Germany-3',
#    'Germany/United States',
#    'Great Britain/Germany',
#    'Gustel V',
#    'Gustel X',
#    'Gustl XI',
#    'Ludwigshafener Ruder Verein-1',
#    'Ludwigshafener Ruderverein',
#    'Macky VI',
#    'Mutafo',
#    'Nirwana',
#    'Paka V',
#    'Rostock',
#    'Satchmo',
#    'Subbnboana',
#    'Tantalus',
#    'Tilly',
#    'Tom Kyle',
#    'Wannsee',
#    'Wendehals']),
#  ('GRE',
#   ['Athens-2',
#    'Ethnikos Gymnastikos Syllogos',
#    'Greece',
#    'Greece-1',
#    'Greece-2',
#    'Greece-3',
#    'Greece-4',
#    '"Lemzos Thorichton ""Psara""-3"',
#    '"Lemzos Thorichton ""Spetsai""-4"',
#    '"Life boat naval ship ""Spetsai""-1"',
#    'Marie-Tim',
#    'Nautikos Omilos-3',
#    'Nephos I',
#    'Nikh',
#    'Nirefs',
#    'Olympion',
#    'Omas Helliniki P. S.',
#    'Omilos Ereton Peiraios-2',
#    'Omilos Ereton Smyrnis',
#    'Pan-Hellenic Athletic Club',
#    'Panhellenios Gymnastikos Syllogos-1',
#    'Peiraikos Syndesmos-2',
#    '"Phalainis ton Thorichtou ""Hydra""-2"',
#    '"Phalainis ton Thorichtou ""Psara""-3"',
#    'Proteus II',
#    'Thessalonki-1',
#    'Zefyros']),
#  ('ANZ', ['Australasia', 'Sydney Rowing Club']),
#  ('AZE', ['Azerbaijan']),
#  (' Paris"', ['"Bagatelle Polo Club']),
#  ('BIZ', ['Belize']),
#  ('FIN',
#   ['Bella',
#    'Bremen',
#    'Chaje II',
#    'Finland',
#    'Finland-1',
#    'Finland-2',
#    'Finn II',
#    'Heatherbell',
#    'Helsingfors R. K.',
#    'Inga-Lill XXXXIII',
#    'Lucky Girl-1',
#    'Lucky Star',
#    'Lynn',
#    'Nina',
#    'Raili',
#    'Ralia',
#    'Rififi',
#    'rn-2',
#    'Sheerio',
#    'Squid III',
#    'Teresita',
#    'Tu-Fri',
#    'Xantippa']),
#  ('BHU', ['Bhutan']),
#  (' Rugby"', ['"BLO Polo Club']),
#  ('BOT', ['Botswana']),
#  ('BUL', ['Bulgaria', 'Bulgaria-1', 'Bulgaria-2']),
#  ('CAM', ['Cambodia', 'GyoshuII']),
#  ('CMR', ['Cameroon']),
#  ('CAY', ['Cayman Islands']),
#  ('CAF', ['Central African Republic']),
#  ('CHA', ['Chad']),
#  ('CHI', ['Chile', 'Mainz']),
#  ('TPE', ['Chinese Taipei', 'Chinese Taipei-1', 'Chinese Taipei-2']),
#  ('WIF', ['Circus', 'West Indies Federation']),
#  ('CIV', ["Cote d'Ivoire"]),
#  ('CRO', ['Croatia']),
#  ('CUB',
#   ['Cuba', 'Cuba-1', 'Cuba-2', 'Hatuey', 'Kurush II', 'Kurush IV', 'Vesania']),
#  ('CYP', ['Cyprus']),
#  ('CZE', ['Czech Republic', 'Czech Republic-1', 'Czech Republic-2']),
#  ('POL', ['Danuta', 'Poland', 'Poland-1', 'Poland-2', 'Poland-3']),
#  ('DMA', ['Dominica']),
#  ('ESA', ['El Salvador']),
#  ('GEQ', ['Equatorial Guinea']),
#  ('ERI', ['Eritrea']),
#  ('VEN', ['Espuma del Mar', 'Venezuela']),
#  ('ETH', ['Ethiopia']),
#  ('FSM', ['Federated States of Micronesia']),
#  ('FIJ', ['Fiji']),
#  ('TTO', ['Firebird II', 'Trinidad and Tobago']),
#  ('GAM', ['Gambia']),
#  (' Hamburg-2"', ['"Germania Ruder Club']),
#  ('GHA', ['Ghana']),
#  ('GUA', ['Guatemala']),
#  ('GBS', ['Guinea Bissau']),
#  ('GUY', ['Guyana']),
#  ('HAI', ['Haiti']),
#  ('NZL',
#   ['Harmony',
#    'Jest',
#    'New Zealand',
#    'New Zealand-1',
#    'New Zealand-2',
#    'Pandora',
#    'Red Dragon']),
#  ('HON', ['Honduras']),
#  ('HKG', ['Hong Kong', 'Hong Kong-1', 'Hong Kong-2', 'Phoenix']),
#  ('IRI', ['Iran']),
#  ('IRQ', ['Iraq']),
#  ('JOR', ['Jordan']),
#  ('KAZ', ['Kazakhstan']),
#  ('KGZ', ['Kyrgyzstan']),
#  (' Central Naval Prep School ""Poros""-1"', ['"Large boat']),
#  ('LAT', ['Latvia', 'Latvia-1', 'Latvia-2']),
#  ('LES', ['Lesotho']),
#  ('LBR', ['Liberia']),
#  ('THA',
#   ['Linglom',
#    'Siames-Cat',
#    'Thailand',
#    'Thailand-1',
#    'Thailand-2',
#    'Tichiboo']),
#  ('LUX', ['Luxembourg', 'Luxembourg-1', 'Luxembourg-2']),
#  ('MKD', ['Macedonia']),
#  ('MAL', ['Malaya']),
#  ('MAS', ['Malaysia', 'Malaysia-1', 'Malaysia-2']),
#  ('MLI', ['Mali']),
#  ('MTN', ['Mauritania']),
#  ('MRI', ['Mauritius', 'Mauritius-1', 'Mauritius-2']),
#  ('MDA', ['Moldova']),
#  ('MNE', ['Montenegro']),
#  ('NRU', ['Nauru']),
#  (' New York"', ['"New York Turnverein']),
#  ('NCA', ['Nicaragua']),
#  ('NBO', ['North Borneo']),
#  ('YAR', ['North Yemen']),
#  (' Brooklyn"', ['"Norwegier Turnverein']),
#  ('OMA', ['Oman']),
#  ('PLW', ['Palau']),
#  ('PLE', ['Palestine']),
#  ('PAR', ['Paraguay']),
#  ('RHO', ['Peri', 'Rhodesia']),
#  ('PER', ['Peru']),
#  (' Philadelphia"', ['"Philadelphia Turngemeinde']),
#  ('QAT', ['Qatar']),
#  ('ROT', ['Refugee Olympic Athletes']),
#  ('ROU', ['Romania', 'Romania-1', 'Romania-2']),
#  ('RWA', ['Rwanda']),
#  ('SAA', ['Saar']),
#  ('LCA', ['Saint Lucia']),
#  ('SAM', ['Samoa']),
#  ('STP', ['Sao Tome and Principe']),
#  ('KSA', ['Saudi Arabia']),
#  ('SEY', ['Seychelles']),
#  ('SVK', ['Slovakia', 'Slovakia-1', 'Slovakia-2']),
#  (' Detroit"', ['"Socialer Turnverein']),
#  ('SOL', ['Solomon Islands']),
#  ('SOM', ['Somalia']),
#  ('KOR', ['South Korea', 'South Korea-1', 'South Korea-2']),
#  ('SUR', ['Suriname']),
#  ('SWZ', ['Swaziland']),
#  ('TJK', ['Tajikistan']),
#  ('TAN', ['Tanzania']),
#  ('TLS', ['Timor Leste']),
#  (' Cleveland"', ['"Turnverein Vorwrts']),
#  ('UAE', ['United Arab Emirates']),
#  ('ISV',
#   ['United States Virgin Islands',
#    'United States Virgin Islands-1',
#    'United States Virgin Islands-2']),
#  ('UZB', ['Uzbekistan', 'Uzbekistan-1', 'Uzbekistan-2']),
#  ('NOC', ['Team']),
#  ('AUT',
#   ['30. Februar',
#    'Austria',
#    'Austria-1',
#    'Austria-2',
#    'Breslau',
#    'Brigantia',
#    'Donar III',
#    'Evita VI',
#    'May-Be 1960',
#    'Surprise']),
#  ('MEX',
#   ['A North American Team',
#    'Acipactli',
#    'Chamukina',
#    'Mexico',
#    'Mexico-1',
#    'Mexico-2',
#    'Nausikaa 4',
#    'Tlaloc',
#    'Xolotl']),
#  ('SUI',
#   ['Alain IV',
#    'Ali-Baba IV',
#    'Ali-Baba IX',
#    'Ali-Baba VI',
#    'Baccara',
#    'Ballerina IV',
#    'Fantasio III',
#    'Kln',
#    'Lerina',
#    'Pousse-Moi Pas VII',
#    'Switzerland',
#    'Switzerland-1',
#    'Switzerland-2',
#    'Tim-Tam III',
#    'Ylliam II',
#    'Ylliam VII',
#    'Ylliam VIII']),
#  ('ALB', ['Albania']),
#  ('FRA',
#   ['Alcyon-6',
#    'Alcyon-7',
#    'Allegro',
#    'Amulet-3',
#    'Amulet-7',
#    'Ariette-10',
#    'Ariette-8',
#    'Astrid III',
#    'Baby-1',
#    'Baby-9',
#    'C.V.A.-14',
#    'C.V.A.-7',
#    'Calimucho',
#    'Calypse II',
#    'Camille',
#    'Carabinier-15',
#    'Carabinier-5',
#    "Cercle de l'Aviron Roubaix-4",
#    'Cercle Nautique de Reims-4',
#    'Cinara-13',
#    'Club Nautique de Dieppe-5',
#    'Club Nautique de Franais-1',
#    'Club Nautique de Lyon-2',
#    'Colette-10',
#    'Colette-12',
#    'Compigne Polo Club',
#    'Crabe I-11',
#    'Crabe I-2',
#    'Crabe I-3',
#    'Crabe II-1',
#    'Crabe II-12',
#    'Crabe II-4',
#    'Crocodile-11',
#    'Crocodile-13',
#    'Cupidon Viking',
#    'Damoiselle',
#    'Demi-Mondaine-15',
#    'Demi-Mondaine-17',
#    'Diabolo St Maurice',
#    'Dick-8',
#    'Ducky-16',
#    'Ducky-4',
#    'EA II',
#    'Eissero VI',
#    'Esterel-1',
#    'Fada',
#    'Fantlet-2',
#    'Fantlet-7',
#    'Favorite-1',
#    'Favorite-17',
#    'Femur-1',
#    'Femur-18',
#    'France',
#    'France-1',
#    'France-2',
#    'France-3',
#    'France-4',
#    'Freia-19',
#    'Freia-5',
#    'Frip IV',
#    'Galopin-20',
#    'Galopin-9',
#    'Gam II',
#    'Gilliatt V',
#    'Giselle-6',
#    'Gitana-2',
#    'Gitana-21',
#    'Guyoni',
#    'Gwendoline-2',
#    'Gwendoline-22',
#    'Gyp-23',
#    'Gyp-6',
#    'Hb-20',
#    'Hb-24',
#    'Jeanette-25',
#    'Jeannette-18',
#    'Kannibaltje',
#    "L'Aile VI",
#    'LaBandera',
#    'Leipzig',
#    'Libellule de Paris',
#    'Libellule de Paris-3',
#    'Mac Miche',
#    'Mamie-4',
#    'Mamie-6',
#    'Marsouin-26',
#    'Marsouin-8',
#    'Martha-1',
#    'Martha-27',
#    'Mascaret-28',
#    'Mascaret-4',
#    'Mignon-29',
#    'Mignon-3',
#    'Namoussa',
#    'Nina Claire-2',
#    'Nina Claire-30',
#    'Olle',
#    'Pettit-Poucet-6',
#    'Pierre et Jean-3',
#    'Pierre et Jean-4',
#    'Pigoule',
#    'Pirouette-31',
#    'Pirouette-5',
#    'Plume-patte-32',
#    'Plume-Patte-5',
#    'Pupilles de Neptune de Lille #1-3',
#    'Pupilles de Neptune de Lille #2-1',
#    'Pupilles de Neptune de Lille-1',
#    "Qu'Importe",
#    'Quand-Mme-2',
#    'Quand-Mme-33',
#    'Racing Club de France',
#    'Red Indian',
#    'Rose Pompon',
#    'Rowing Club Castillon-3',
#    'Rozenn-3',
#    'Sandra',
#    'Sarcelle-3',
#    'Sarcelle-35',
#    'Scamasaxe-2',
#    'Scamasaxe-3',
#    'Scamasaxe-34',
#    'Sidi Fekkar-36',
#    'Sidi-Fekkar-14',
#    'Singy-37',
#    'Singy-7',
#    'Snowten III',
#    'Societ Nautique de la Marne',
#    'Societ Nautique de la Marne-1',
#    'Societ Nautique de la Marne-3',
#    'Socit Nautique de Bayonne',
#    'Socit Nautique de Bayonne-1',
#    'Socit Nautique de Bayonne-2',
#    'Socit Nautique de la Basse Seine-1',
#    'Socit Nautique de la Basse Seine-2',
#    'Souriceau-38',
#    'Souriceau-4',
#    'Souvenance',
#    'Stade Franais AC-2',
#    'Suzon IV-39',
#    'Suzon IV-5',
#    'Tornade-16',
#    'Tournade-40',
#    'Tramontane',
#    'Tritons Lillois-2',
#    'Turquoise-1',
#    'Turquoise-3',
#    'Union des Socits Franais de Sports Athletiques',
#    'United States/France',
#    'USFSA',
#    'Verveine-19',
#    'Verveine-41',
#    'Virginie',
#    'Whitini Star']),
#  ('ITA',
#   ['Aldebaran',
#    'Aldebaran II',
#    'Aretusa',
#    'Argeste',
#    'Augsburg',
#    'Ausonia',
#    'Bamba',
#    'Barion/Bari-2',
#    'Bucintoro Venezia',
#    'Bucintoro Venezia-1',
#    'Ciocca',
#    'Ciocca II',
#    'Enotria',
#    'Esperia',
#    'Galatea II',
#    'Grifone',
#    'Italia',
#    'Italy',
#    'Italy-1',
#    'Italy-2',
#    'Italy-3',
#    'Legionario',
#    '"Marinai della nave da guerra ""Varese"""',
#    'Mebi',
#    'Merope',
#    'Merope III',
#    'Mirtala',
#    'Pegaso',
#    'Pistoja/Firenze',
#    'Roma',
#    'Romolo',
#    'Twins II',
#    'Twins VIII',
#    'Umberta V',
#    'Venilia',
#    'Voloira II']),
#  ('ALG', ['Algeria']),
#  ('SWE',
#   ['Ali-Baba II',
#    'Aloha II',
#    'Bissbi',
#    'Briar',
#    'Chance',
#    'Denmark/Sweden',
#    'Elsie',
#    'Erna Signe',
#    'Floresco',
#    'Freja',
#    'Galejan',
#    'Gteborgs Roddfrening-2',
#    'Gteborgs Roddklubb-1',
#    'Hayama',
#    'Hojwa',
#    'Humbug V',
#    'Ilderim',
#    'Ingegerd',
#    'K.S.S.S. 1912-2',
#    'Kerstin-1',
#    'Kitty-1',
#    'Kuling',
#    'Kullan',
#    'Lasha',
#    'Lotta IV',
#    'Marga-2',
#    'Mari',
#    'May Be',
#    'May Be VII',
#    'Roddklubben af 1912-1',
#    'Roddklubben af 1912-2',
#    'Rush V',
#    'Rush VII',
#    'Saga-2',
#    'Sans Atout-1',
#    'Sass-2',
#    'Sif',
#    'Sjovinge',
#    'Slaghoken',
#    'Slaghoken II',
#    'Solos Carex',
#    'Sunshine',
#    'Sweden',
#    'Sweden-1',
#    'Sweden-2',
#    'Sweden-3',
#    'Sweden-4',
#    'Swedish Star',
#    'Sylvia',
#    'Tornado',
#    'Vaxholm Roddklubb',
#    'Vinga-1']),
#  ('URS',
#   ['Almaz',
#    'Burevestnik',
#    'Druzhba',
#    'Kon-Tiki',
#    'Korshun',
#    'Neptun II',
#    'Nokaut II',
#    'Olen',
#    'Persey',
#    'Soviet Union',
#    'Soviet Union-1',
#    'Soviet Union-2',
#    'Soviet Union-3',
#    'Tulilind',
#    'Uragan',
#    'Viktoriya']),
#  ('ASA', ['American Samoa']),
#  ('ESP',
#   ['Amolgavar',
#    'Canopus',
#    'Fruits',
#    'Galerna',
#    'Pasodoble',
#    'Posillipo III',
#    'Ral-Club Barcelona',
#    'Spain',
#    'Spain-1',
#    'Spain-2',
#    'Tajamar']),
#  ('NED',
#   ['Amstel Amsterdam',
#    'Barco Deloro',
#    'Beatrijs III-1',
#    'Bem II',
#    'Boreas-2',
#    'Daisy',
#    'DeRuyter',
#    'Holland',
#    'Hollandia',
#    'Joy',
#    'Kemphaan',
#    'Mascotte',
#    'Minerva Amsterdam',
#    'Nadine',
#    'Netherlands',
#    'Netherlands-1',
#    'Netherlands-2',
#    'Nrnberg',
#    'Oranje',
#    'Salinero',
#    'St. Margrite',
#    'Starita',
#    'Sunrise',
#    'Thalatta',
#    'Trintel II',
#    'Willem-Six']),
#  ('GBR',
#   ['Ancora',
#    'Andromeda',
#    'Beaver',
#    'Bluebottle',
#    'Bona Fide',
#    'Brat',
#    'Brynhild-2',
#    'Cambridge University Boat Club-2',
#    'Ceres II',
#    'Chuckles',
#    'Cicely-1',
#    'Cobweb-1',
#    'Cornwall',
#    'Devon and Somerset Wanderers',
#    'Dormy-1',
#    'Dylan-2',
#    'Emily',
#    'England',
#    'England-1',
#    'Feo',
#    'Fortuna',
#    'France/Great Britain',
#    'Gem II',
#    'Great Britain',
#    'Great Britain-1',
#    'Great Britain-2',
#    'Great Britain-3',
#    'Great Britain-4',
#    'Gyrinus-1',
#    'Hera-1',
#    'Heroine',
#    'Hurlingham-2',
#    'Ireland-3',
#    'Johan',
#    'K Division Metropolitan Police Team-3',
#    'Lady C',
#    'Lalage',
#    'Lancet',
#    'Laurea-1',
#    'Leander Club #1-1',
#    'Leander Club #2-2',
#    'Leander Club-1',
#    'Leander Club-2',
#    'Liverpool Police Team-2',
#    'London City Police-1',
#    'Magdalen College Boat Club-1',
#    'Mistral Hojris',
#    'Moseley Wanderers',
#    'Mouchette-2',
#    'Nan-2',
#    'Paka',
#    'Potsdam',
#    'Quicksilver-2',
#    'Roehampton-1',
#    'Sabre',
#    'Salamander',
#    'Saskia',
#    'Scotia',
#    'Scotland',
#    'Scotland-2',
#    'Scotland-3',
#    'Sea Dog-2',
#    'Sibindi-2',
#    'Smyrna',
#    'Sorais-2',
#    'Starlight III',
#    'Swift',
#    'Thames Rowing Club',
#    'Titia',
#    'Twinkle',
#    'Unique',
#    'Upton Park FC',
#    'Vision',
#    'Wales-4',
#    'Wolseley-Siddeley-1',
#    'Yeoman VII',
#    'Yeoman XII']),
#  ('BRA',
#   ['Andorinha',
#    'Brazil',
#    'Brazil-1',
#    'Brazil-2',
#    'Bu III',
#    'Buscape II',
#    'Clementine V',
#    'Escapade',
#    'Inca',
#    'Lbeck',
#    'Pimm',
#    'Terrible',
#    'Vento Sul']),
#  ('AND', ['Andorra']),
#  ('BEL',
#   ['Antwerpia V',
#    'Belgium',
#    'Belgium-1',
#    'Belgium-2',
#    'Belgium-3',
#    'Belgium-4',
#    'Brussels Swimming and Water Polo Club',
#    'Ciss',
#    'Danzig',
#    'Dolfijn',
#    'Edelweiss II-1',
#    'Freddy',
#    'Girl Pat',
#    'Meteor',
#    'Royal Club Nautique de Gand',
#    'Suzy-2',
#    'Tan-Fe-Pah',
#    'Ubu',
#    'Univ. of Brussels',
#    'Zut']),
#  ('NOR',
#   ['Apache',
#    'Atlanta',
#    'Bera',
#    'Eleda',
#    'Elisabeth V',
#    'Elisabeth X',
#    'Encore',
#    'Fornebo',
#    'Fram',
#    'Fram III',
#    'Hamburg',
#    'Heira II',
#    'Irene',
#    'Jo',
#    'KNS',
#    'Kristiania Roklub',
#    'Kristiania Roklub-1',
#    'Lett',
#    'Lucky',
#    'Lully II',
#    'Lyn-2',
#    'Magda IX',
#    'Marmi II-1',
#    'Monica',
#    'Mosk II',
#    'Nora',
#    'Noreg',
#    'Norna',
#    'Norway',
#    'Norway-1',
#    'Norway-2',
#    'Norway-3',
#    'Norwegian Rowing Association',
#    'Ormsund Roklub-2',
#    'Pan',
#    'Pan II',
#    'Sildra-1',
#    'Silja',
#    'Sirene',
#    'Sonja II',
#    'Stella-2',
#    'Struten',
#    'Studenternes Roklub-2',
#    'Taifun',
#    'Viking']),
#  ('ARM', ['Armenia']),
#  ('ARU', ['Aruba']),
#  ('BAH',
#   ['Bahamas',
#    'Bim',
#    'Combine',
#    'Gem',
#    'Gem III',
#    'Gem IV',
#    'Gem VII',
#    'Guanahani',
#    'John B',
#    'Yeoman']),
#  ('BRN', ['Bahrain']),
#  ('URU', ['Bajazzo', 'Heidelberg', 'Nortazo', 'Uruguay']),
#  ('HUN',
#   ['Balaton',
#    'Hungaria',
#    'Hungaria Evezos Egylet',
#    'Hungary',
#    'Hungary-1',
#    'Hungary-2',
#    'Hungary-3',
#    'Knigsberg',
#    'Olimpia',
#    'Pannonia RC/National RC']),
#  ('BAN', ['Bangladesh']),
#  ('BAR', ['Barbados']),
#  ('BLR', ['Belarus', 'Belarus-1', 'Belarus-2']),
#  ('BEN', ['Benin']),
#  ('BER',
#   ['Bermuda', 'Bermudes', 'Bermudian', 'Oleander II', 'Oleander XII', 'Pam']),
#  ('RSA',
#   ['Boer Team',
#    'Hakahana',
#    'Impala',
#    'Shoveller',
#    'South Africa',
#    'South Africa-1',
#    'South Africa-2',
#    'Springbok',
#    'Yeoman V']),
#  ('BOH',
#   ['Bohemia', 'Bohemia-1', 'Bohemia-2', 'Bohemia-3', 'Bohemia/Great Britain']),
#  ('BOL', ['Bolivia']),
#  ('JPN',
#   ['Boreas',
#    'Danaldo',
#    'Dow Jones',
#    'Essen',
#    'Japan',
#    'Japan-1',
#    'Japan-2',
#    'Japan-3',
#    'Miss Nippon V',
#    'MitaII',
#    'Myojo',
#    'Rambo',
#    'Riccar',
#    'Roy',
#    'Whisper']),
#  ('BIH', ['Bosnia and Herzegovina']),
#  ('EST', ['Brandenburg', 'Estonia', 'Tutti V']),
#  ('IVB', ['British Virgin Islands']),
#  ('BRU', ['Brunei']),
#  ('BUR', ['Burkina Faso']),
#  ('BDI', ['Burundi']),
#  ('RUS',
#   ['Bylina-2',
#    'Gallia II',
#    'Norman-1',
#    'Russia',
#    'Russia-1',
#    'Russia-2',
#    'Russia-3']),
#  ('CPV', ['Cape Verde']),
#  (' Chicago"',
#   ['"Central Turnverein', '"La Salle Turnverein', '"Turnverein Vorwrts']),
#  ('YUG',
#   ['Cha-Cha III',
#    'Konstanz',
#    'Primorka',
#    'Yugoslavia',
#    'Yugoslavia-1',
#    'Yugoslavia-2']),
#  ('CHN', ['China', 'China-1', 'China-2', 'China-3']),
#  ('COL', ['Colombia']),
#  ('COM', ['Comoros']),
#  (' St Louis"', ['"Concordia Turnverein', '"South St Louis Turnverein']),
#  ('CGO', ['Congo (Brazzaville)']),
#  ('COD', ['Congo (Kinshasa)']),
#  ('COK', ['Cook Islands']),
#  ('CRC', ['Costa Rica']),
#  ('CRT', ['Crete']),
#  ('TUR', ['Cuxhaven', 'Marmara', 'Turkey']),
#  ('TCH',
#   ['Czechoslovakia',
#    'Czechoslovakia-1',
#    'Czechoslovakia-2',
#    'Czechoslovakia-3']),
#  ('MON', ['Damoiselle IV', 'Hirondelle', 'Monaco', 'Monaco-1', 'Monaco-2']),
#  (' Davenport"', ['"Davenport Turngemeinde']),
#  ('DJI', ['Djibouti']),
#  ('DOM', ['Dominican Republic']),
#  ('GDR',
#   ['East Germany', 'East Germany-1', 'East Germany-2', 'East Germany-3']),
#  ('ECU', ['Ecuador']),
#  ('EGY', ['Egypt']),
#  ('GAB', ['Gabon']),
#  ('GEO', ['Georgia']),
#  (' Hamburg"', ['"Germania Ruder Club']),
#  ('GRN', ['Grenada']),
#  ('GUM', ['Guam']),
#  ('GUI', ['Guinea']),
#  ('ISL', ['Iceland']),
#  ('IND', ['India', 'India-1', 'India-2']),
#  ('IOA', ['Individual Olympic Athletes']),
#  ('INA', ['Indonesia', 'Indonesia-1', 'Indonesia-2', 'Partenope', 'Tengiri']),
#  ('ISR', ['Israel', 'Israel-1', 'Israel-2']),
#  ('JAM', ['Jamaica', 'Jamaica-1', 'Jamaica-2', 'Miss Nippon IV']),
#  ('SGP',
#   ['June Climene', 'Rika II', 'Singapore', 'Singapore-1', 'Singapore-2']),
#  ('PHI', ['Kalayaan', 'Patricia', 'Philippines']),
#  ('KEN', ['Kenya']),
#  ('MYA', ['Kingfisher', 'Myanmar', 'Yangon']),
#  ('KIR', ['Kiribati']),
#  ('KOS', ['Kosovo']),
#  ('KUW', ['Kuwait']),
#  ('LAO', ['Laos']),
#  ('LIB', ['Lebanon', 'Maid of Lebanon']),
#  ('LBA', ['Libya']),
#  ('LIE', ['Liechtenstein']),
#  ('LTU', ['Lithuania']),
#  ('MAD', ['Madagascar']),
#  ('MAW', ['Malawi']),
#  ('MDV', ['Maldives']),
#  ('MLT', ['Malta']),
#  ('MHL', ['Marshall Islands']),
#  (' Milwaukee"', ['"Milwaukee Turnverein']),
#  ('MGL', ['Mongolia']),
#  ('MAR', ['Morocco']),
#  ('MOZ', ['Mozambique']),
#  ('NAM', ['Namibia']),
#  ('NEP', ['Nepal']),
#  ('AHO', ['Netherlands Antilles']),
#  (' Oxford-2"', ['"New College']),
#  ('NFL', ['Newfoundland']),
#  ('NIG', ['Niger']),
#  ('NGR', ['Nigeria', 'Nigeria-1', 'Nigeria-2']),
#  ('PRK', ['North Korea', 'North Korea-1', 'North Korea-2']),
#  (' Manchester"', ['"Osborne Swimming Club']),
#  ('PAK', ['Pakistan']),
#  ('PAN', ['Panama']),
#  ('PNG', ['Papua New Guinea']),
#  (' Passaic"', ['"Passaic Turnverein']),
#  ('ZIM', ['Peri II', 'Zimbabwe']),
#  ('PUR', ['Puerto Rico', 'Puerto Rico-1', 'Puerto Rico-2']),
#  (' Leitmeritz"', ['"R.-V. Germania']),
#  ('SKN', ['Saint Kitts and Nevis']),
#  ('VIN', ['Saint Vincent and the Grenadines']),
#  ('SMR', ['San Marino']),
#  ('SEN', ['Senegal']),
#  ('SRB', ['Serbia', 'Serbia-1', 'Serbia-2']),
#  ('SCG', ['Serbia and Montenegro']),
#  ('SLE', ['Sierra Leone']),
#  ('SLO', ['Slovenia', 'Slovenia-1', 'Slovenia-2']),
#  ('SSD', ['South Sudan']),
#  ('VNM', ['South Vietnam']),
#  ('YMD', ['South Yemen']),
#  ('SRI', ['Sri Lanka']),
#  ('SUD', ['Sudan']),
#  ('SYR', ['Syria']),
#  ('TOG', ['Togo']),
#  ('TGA', ['Tonga']),
#  ('TUN', ['Tunisia']),
#  ('TKM', ['Turkmenistan']),
#  ('TUV', ['Tuvalu']),
#  ('UGA', ['Uganda']),
#  ('UKR', ['Ukraine', 'Ukraine-1', 'Ukraine-2']),
#  ('EUN',
#   ['Unified Team', 'Unified Team-1', 'Unified Team-2', 'Unified Team-3']),
#  ('UAR', ['United Arab Republic']),
#  ('UNK', ['Unknown']),
#  ('VAN', ['Vanuatu']),
#  ('VIE', ['Vietnam']),
#  ('FRG',
#   ['West Germany', 'West Germany-1', 'West Germany-2', 'West Germany-3']),
#  ('YEM', ['Yemen']),
#  ('ZAM', ['Zambia'])]

# %%
equiposOlimpicosRDD.map(lambda x : (x[2],x[1])).groupByKey().mapValues(len).collect()
# Out:
# [('ARG', 18),
#  ('AFG', 1),
#  ('IRL', 7),
#  ('POR', 21),
#  ('AUS', 23),
#  ('USA', 79),
#  ('ANG', 1),
#  ('DEN', 28),
#  ('ANT', 1),
#  ('CAN', 31),
#  ('GER', 37),
#  ('GRE', 27),
#  ('ANZ', 2),
#  ('AZE', 1),
#  (' Paris"', 1),
#  ('BIZ', 1),
#  ('FIN', 23),
#  ('BHU', 1),
#  (' Rugby"', 1),
#  ('BOT', 1),
#  ('BUL', 3),
#  ('CAM', 2),
#  ('CMR', 1),
#  ('CAY', 1),
#  ('CAF', 1),
#  ('CHA', 1),
#  ('CHI', 2),
#  ('TPE', 3),
#  ('WIF', 2),
#  ('CIV', 1),
#  ('CRO', 1),
#  ('CUB', 7),
#  ('CYP', 1),
#  ('CZE', 3),
#  ('POL', 5),
#  ('DMA', 1),
#  ('ESA', 1),
#  ('GEQ', 1),
#  ('ERI', 1),
#  ('VEN', 2),
#  ('ETH', 1),
#  ('FSM', 1),
#  ('FIJ', 1),
#  ('TTO', 2),
#  ('GAM', 1),
#  (' Hamburg-2"', 1),
#  ('GHA', 1),
#  ('GUA', 1),
#  ('GBS', 1),
#  ('GUY', 1),
#  ('HAI', 1),
#  ('NZL', 7),
#  ('HON', 1),
#  ('HKG', 4),
#  ('IRI', 1),
#  ('IRQ', 1),
#  ('JOR', 1),
#  ('KAZ', 1),
#  ('KGZ', 1),
#  (' Central Naval Prep School ""Poros""-1"', 1),
#  ('LAT', 3),
#  ('LES', 1),
#  ('LBR', 1),
#  ('THA', 6),
#  ('LUX', 3),
#  ('MKD', 1),
#  ('MAL', 1),
#  ('MAS', 3),
#  ('MLI', 1),
#  ('MTN', 1),
#  ('MRI', 3),
#  ('MDA', 1),
#  ('MNE', 1),
#  ('NRU', 1),
#  (' New York"', 1),
#  ('NCA', 1),
#  ('NBO', 1),
#  ('YAR', 1),
#  (' Brooklyn"', 1),
#  ('OMA', 1),
#  ('PLW', 1),
#  ('PLE', 1),
#  ('PAR', 1),
#  ('RHO', 2),
#  ('PER', 1),
#  (' Philadelphia"', 1),
#  ('QAT', 1),
#  ('ROT', 1),
#  ('ROU', 3),
#  ('RWA', 1),
#  ('SAA', 1),
#  ('LCA', 1),
#  ('SAM', 1),
#  ('STP', 1),
#  ('KSA', 1),
#  ('SEY', 1),
#  ('SVK', 3),
#  (' Detroit"', 1),
#  ('SOL', 1),
#  ('SOM', 1),
#  ('KOR', 3),
#  ('SUR', 1),
#  ('SWZ', 1),
#  ('TJK', 1),
#  ('TAN', 1),
#  ('TLS', 1),
#  (' Cleveland"', 1),
#  ('UAE', 1),
#  ('ISV', 3),
#  ('UZB', 3),
#  ('NOC', 1),
#  ('AUT', 10),
#  ('MEX', 9),
#  ('SUI', 17),
#  ('ALB', 1),
#  ('FRA', 154),
#  ('ITA', 36),
#  ('ALG', 1),
#  ('SWE', 52),
#  ('URS', 16),
#  ('ASA', 1),
#  ('ESP', 11),
#  ('NED', 26),
#  ('GBR', 77),
#  ('BRA', 13),
#  ('AND', 1),
#  ('BEL', 20),
#  ('NOR', 45),
#  ('ARM', 1),
#  ('ARU', 1),
#  ('BAH', 10),
#  ('BRN', 1),
#  ('URU', 4),
#  ('HUN', 10),
#  ('BAN', 1),
#  ('BAR', 1),
#  ('BLR', 3),
#  ('BEN', 1),
#  ('BER', 6),
#  ('RSA', 9),
#  ('BOH', 5),
#  ('BOL', 1),
#  ('JPN', 15),
#  ('BIH', 1),
#  ('EST', 3),
#  ('IVB', 1),
#  ('BRU', 1),
#  ('BUR', 1),
#  ('BDI', 1),
#  ('RUS', 7),
#  ('CPV', 1),
#  (' Chicago"', 3),
#  ('YUG', 6),
#  ('CHN', 4),
#  ('COL', 1),
#  ('COM', 1),
#  (' St Louis"', 2),
#  ('CGO', 1),
#  ('COD', 1),
#  ('COK', 1),
#  ('CRC', 1),
#  ('CRT', 1),
#  ('TUR', 3),
#  ('TCH', 4),
#  ('MON', 5),
#  (' Davenport"', 1),
#  ('DJI', 1),
#  ('DOM', 1),
#  ('GDR', 4),
#  ('ECU', 1),
#  ('EGY', 1),
#  ('GAB', 1),
#  ('GEO', 1),
#  (' Hamburg"', 1),
#  ('GRN', 1),
#  ('GUM', 1),
#  ('GUI', 1),
#  ('ISL', 1),
#  ('IND', 3),
#  ('IOA', 1),
#  ('INA', 5),
#  ('ISR', 3),
#  ('JAM', 4),
#  ('SGP', 5),
#  ('PHI', 3),
#  ('KEN', 1),
#  ('MYA', 3),
#  ('KIR', 1),
#  ('KOS', 1),
#  ('KUW', 1),
#  ('LAO', 1),
#  ('LIB', 2),
#  ('LBA', 1),
#  ('LIE', 1),
#  ('LTU', 1),
#  ('MAD', 1),
#  ('MAW', 1),
#  ('MDV', 1),
#  ('MLT', 1),
#  ('MHL', 1),
#  (' Milwaukee"', 1),
#  ('MGL', 1),
#  ('MAR', 1),
#  ('MOZ', 1),
#  ('NAM', 1),
#  ('NEP', 1),
#  ('AHO', 1),
#  (' Oxford-2"', 1),
#  ('NFL', 1),
#  ('NIG', 1),
#  ('NGR', 3),
#  ('PRK', 3),
#  (' Manchester"', 1),
#  ('PAK', 1),
#  ('PAN', 1),
#  ('PNG', 1),
#  (' Passaic"', 1),
#  ('ZIM', 2),
#  ('PUR', 3),
#  (' Leitmeritz"', 1),
#  ('SKN', 1),
#  ('VIN', 1),
#  ('SMR', 1),
#  ('SEN', 1),
#  ('SRB', 3),
#  ('SCG', 1),
#  ('SLE', 1),
#  ('SLO', 3),
#  ('SSD', 1),
#  ('VNM', 1),
#  ('YMD', 1),
#  ('SRI', 1),
#  ('SUD', 1),
#  ('SYR', 1),
#  ('TOG', 1),
#  ('TGA', 1),
#  ('TUN', 1),
#  ('TKM', 1),
#  ('TUV', 1),
#  ('UGA', 1),
#  ('UKR', 3),
#  ('EUN', 4),
#  ('UAR', 1),
#  ('UNK', 1),
#  ('VAN', 1),
#  ('VIE', 1),
#  ('FRG', 4),
#  ('YEM', 1),
#  ('ZAM', 1)]

# %%
equiposArgentinos = equiposOlimpicosRDD.filter(lambda l : "ARG" in l)
equiposArgentinos.map(lambda x : [x[1], x[2]]).collect()
# Out:
# [['Acturus', 'ARG'],
#  ['Antares', 'ARG'],
#  ['Arcturus', 'ARG'],
#  ['Ardilla', 'ARG'],
#  ['Argentina', 'ARG'],
#  ['Argentina-1', 'ARG'],
#  ['Argentina-2', 'ARG'],
#  ['Blue Red', 'ARG'],
#  ['Covunco III', 'ARG'],
#  ['Cupidon III', 'ARG'],
#  ['Djinn', 'ARG'],
#  ['Gullvinge', 'ARG'],
#  ['Matrero II', 'ARG'],
#  ['Mizar', 'ARG'],
#  ['Pampero', 'ARG'],
#  ['Rampage', 'ARG'],
#  ['Tango', 'ARG'],
#  ['Wiking', 'ARG']]
